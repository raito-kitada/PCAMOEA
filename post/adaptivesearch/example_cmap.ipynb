# %%
import matplotlib.pyplot as plt
import numpy as np
import sys
import os

# %%
# this path must be modified
moeafw_path = '/rst4_data/workspace6/tatsukawa/Repos/MOEAFramework'

import sys, os
sys.path.append(os.path.join(moeafw_path, 'post/py'))

# %%
import lab.plot as labplt
labplt.plot_cmap('rainbow')

# %%
from lab import plot
plot.plot_cmap('hot')
